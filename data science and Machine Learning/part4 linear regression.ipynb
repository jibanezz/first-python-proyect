# %% [markdown]
# #### Regression is a model which can predict one value based on another value
# ###### for example, if we have a data about size of house and price of house we can predict unknown value

# %%
size = [100,101,95,98,105]
price = [1005,1100,900,950,1200]

# %%
# can you plot size vs price as figure
import matplotlib.pyplot as plt

plt.scatter(size,price)
plt.xlabel('size')
plt.ylabel('price')
plt.title('size vs price')
plt.show()

# %%
import numpy as np
s_i = np.polyfit(size,price,1)
print(s_i)
# Out:
# [   31.58759124 -2121.44160584]

# %%
m = s_i[0]
c = s_i[1]

# %%
o = np.linspace(94,105,100)

plt.scatter(size,price)

plt.plot(o,m*o+c)
plt.legend(['data','mathematical model'])

# %%
import pandas as pd
data = pd.read_csv('Advertising.csv')
data
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
# please sum up TV radio and newspaper 

data['total'] = data['TV'] + data['radio'] + data['newspaper']
data
# Out:
#         TV  radio  newspaper  sales  total
# 0    230.1   37.8       69.2   22.1  337.1
# 1     44.5   39.3       45.1   10.4  128.9
# 2     17.2   45.9       69.3    9.3  132.4
# 3    151.5   41.3       58.5   18.5  251.3
# 4    180.8   10.8       58.4   12.9  250.0
# ..     ...    ...        ...    ...    ...
# 195   38.2    3.7       13.8    7.6   55.7
# 196   94.2    4.9        8.1    9.7  107.2
# 197  177.0    9.3        6.4   12.8  192.7
# 198  283.6   42.0       66.2   25.5  391.8
# 199  232.1    8.6        8.7   13.4  249.4
#
# [200 rows x 5 columns]

# %%
my_data = data[['total','sales']]
my_data
# Out:
#      total  sales
# 0    337.1   22.1
# 1    128.9   10.4
# 2    132.4    9.3
# 3    251.3   18.5
# 4    250.0   12.9
# ..     ...    ...
# 195   55.7    7.6
# 196  107.2    9.7
# 197  192.7   12.8
# 198  391.8   25.5
# 199  249.4   13.4
#
# [200 rows x 2 columns]

# %%
x = my_data['total']
y = my_data['sales']

# %%
plt.scatter(x,y)
plt.xlabel('Total')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
m,c =  np.polyfit(x,y,1)

# %%
o = np.linspace(0,600,100)

plt.scatter(x,y)

plt.plot(o,m*o+c)
plt.legend(['data','mathematical model'])
