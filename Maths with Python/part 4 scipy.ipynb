# %%
def xyz (x):
    return x**2 -20.6*x + 106.09

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: C:\Users\User\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import scipy as sp

# %%
sp.optimize.fmin(xyz,5)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 20
#          Function evaluations: 40
# array([10.29998779])

# %%
xyz(10.29998779)
# Out:
# 1.4907186596246902e-10

# %%
import numpy as np

# %%
data = np.random.randn(100)
data
# Out:
# array([ 7.38731760e-01,  1.84843374e+00,  8.64132300e-01, -1.80041835e-01,
#         1.23364809e+00, -2.81789043e-01, -1.14776761e+00,  2.80685534e+00,
#        -1.38903594e-01,  3.49854264e-01,  1.88538637e+00,  1.76809370e-01,
#        -9.44933727e-01, -5.30445724e-01, -1.04404295e+00,  9.62832767e-01,
#        -1.53172368e+00,  2.84724089e-01, -3.60801581e-01,  8.73694356e-01,
#        -1.43618691e-02,  2.22629680e-01, -1.24213530e-01, -7.90452252e-01,
#         1.23029265e+00,  9.36395526e-01, -2.38263094e-02, -4.61280174e-01,
#         3.85029538e-01,  6.23712227e-01, -3.35708854e-02, -7.98623115e-01,
#        -1.26370965e+00, -1.23971628e+00,  1.15398855e+00, -1.49047880e+00,
#         1.58891780e-01,  1.48663244e+00, -2.32753846e-01,  1.70723671e+00,
#        -2.03958556e+00, -1.39042939e-03, -1.68351484e+00, -7.45924690e-01,
#        -4.85550186e-01,  8.19274411e-01, -7.10744171e-01,  1.27193056e+00,
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(data)

# %%
x,y = sp.signal.find_peaks(data, height=1.5)

# %%
plt.plot(x,data[x],'x')
plt.plot(data)
